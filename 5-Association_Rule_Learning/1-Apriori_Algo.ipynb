# %% [raw]
# Association Rule Learning is a data mining method that discovers relationships between items in large datasets,
#             typically expressed as IF–THEN rules based on support, confidence, and lift

# %% [raw]
# Association rule learning answers questions like:
#     If a customer buys X, what else are they likely to buy?
#         Which items tend to appear together in transactions?

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Data/Market_Basket_Optimisation.csv', header=None)
transactions = []
for i in range(0, 7501):
    transactions.append([str(data.values[i,j]) for j in range(0, 20)])

# %%
from apyori import apriori
rules = apriori(transactions=transactions, min_support=0.003, min_confidence=0.2, min_lift=3, min_length=2, max_length=2)

# %%
results = list(rules)

# %%
def inspect(results):
    lhs = [tuple(result[2][0][0])[0] for result in results]
    rhs = [tuple(result[2][0][1])[0] for result in results]
    supports = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

resultsinDataFrame = pd.DataFrame(
    inspect(results),
    columns=['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift']
)

# %%
resultsinDataFrame.head()
resultsinDataFrame.nlargest(n=10, columns='Lift')
