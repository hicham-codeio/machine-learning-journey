# %% [raw]
# Simple LN : y = b + b*x
# Multi LN : y = b + b*x + b*x + b*x ...
# Polyn LN : y = b + b*x + b*x² + b*x^3 + b*x^4 ...(parabolic line)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('Data/Position_Salaries.csv')
data.info()
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  10 non-null     object
#  1   Level     10 non-null     int64
#  2   Salary    10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
x = data.iloc[:,1:-1].values
y = data.iloc[:,-1].values

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x, y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
x_poly = poly_reg.fit_transform(x)

# %%
from sklearn.linear_model import LinearRegression
lin_reg_2 = LinearRegression()
lin_reg_2.fit(x_poly, y)
# Out:
# LinearRegression()

# %%
print(lin_reg.coef_)
print(lin_reg_2.coef_)
# Out:
# [80878.78787879]
# [      0.         -211002.33100264   94765.44289054  -15463.2867133
#      890.15151515]

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=x, y=y, color='purple')
plt.plot(x, lin_reg.predict(x), color='red')
plt.title('Linear Regression')
plt.xlabel('Position')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
x_poly.shape
# Out:
# (10, 5)

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=x, y=y, color='purple')
plt.plot(x, lin_reg_2.predict(poly_reg.fit_transform(x)), color='red')
plt.title('Linear Regression')
plt.xlabel('Position')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
lin_pred = lin_reg.predict([[6.5]])
poly = poly_reg.fit_transform([[6.5]])
poly_pred = lin_reg_2.predict(poly)

# %%
print(lin_pred)
print(poly_pred)
# Out:
# [330378.78787879]
# [158862.45265152]
